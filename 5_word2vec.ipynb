# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'a', 'anarchism', 'term', 'originated', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.
#
# AdagradOptimizer is used in this example.
# http://sebastianruder.com/optimizing-gradient-descent/

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.660296
# Nearest to its: provence, pelt, predominated, mentally, promenade, badger, indecent, kilometers,
# Nearest to known: rsdlp, meddle, carbohydrate, phylogenetic, upgrade, lemons, knighthood, saddam,
# Nearest to to: massless, cession, vara, celebrates, defer, constantly, indulgent, elohim,
# Nearest to only: programming, blood, censured, wallenberg, doom, steyn, waived, skilled,
# Nearest to such: headings, inlets, maggots, lessing, replaced, tutored, worshippers, gabab,
# Nearest to not: medications, pear, gir, mujahedin, plurality, chopin, assaulting, convinced,
# Nearest to nine: vinyl, wavering, productive, dirichlet, lew, sequel, swept, starfish,
# Nearest to all: ethan, wheelock, summations, spent, exchanging, giuliani, partido, cookery,
# Nearest to over: publique, network, ideograms, allahabad, ecoregion, flushed, depression, demarcation,
# Nearest to with: contemplative, rowspan, hitpa, explaining, threat, monarchist, immortals, hemingway,
# Nearest to first: illustration, blame, ruud, mysore, appleseed, friulian, euro, goddesses,
# Nearest to many: petronas, hunt, terribly, helpers, bianchi, rip, warn, surmised,
# Nearest to b: descendants, endocrine, renminbi, incessant, woman, presenting, cth, do,
# Nearest to had: mattia, gigi, tosses, river, hispaniola, ack, lilongwe, split,
# Nearest to he: wil, summertime, trinidad, rsha, boss, spinning, tammy, strut,
# Nearest to after: meninges, blackadder, longed, comanche, wing, workshops, heavenly, datatype,
# Average loss at step 2000: 4.361486
# Average loss at step 4000: 3.865126
# Average loss at step 6000: 3.794614
# Average loss at step 8000: 3.686161
# Average loss at step 10000: 3.609517
# Nearest to its: his, their, the, laude, pulsed, bowen, medalists, accomplices,
# Nearest to known: such, rsdlp, steffi, meddle, tz, well, upgrade, wwii,
# Nearest to to: not, blinded, baritone, constantly, would, adobe, will, harrison,
# Nearest to only: programming, every, do, ecommerce, stairs, waived, ammi, samoa,
# Nearest to such: known, gabab, hci, worshippers, lessing, toughest, tile, replaced,
# Nearest to not: it, they, medications, never, to, generally, which, nullify,
# Nearest to nine: eight, six, seven, five, zero, three, four, two,
# Nearest to all: partido, mantis, ethan, wheelock, summations, professors, always, metamorphism,
# Nearest to over: network, demarcation, flushed, depression, hungry, prickly, comparison, ideograms,
# Nearest to with: in, into, macedonian, sainte, projected, arndt, by, at,
# Nearest to first: ruud, medes, slashdot, past, amnon, euro, second, best,
# Nearest to many: some, several, duties, terribly, taylor, nottinghamshire, monuments, incident,
# Nearest to b: d, realtime, incessant, jihad, physical, maestro, gesenius, passau,
# Nearest to had: has, was, have, paleontologists, split, started, gigi, were,
# Nearest to he: it, they, she, who, summertime, there, coinage, rice,
# Nearest to after: inuktitut, monophysites, gbc, before, comanche, until, roster, at,
# Average loss at step 12000: 3.606798
# Average loss at step 14000: 3.570859
# Average loss at step 16000: 3.405539
# Average loss at step 18000: 3.455449
# Average loss at step 20000: 3.544312
# Nearest to its: their, his, the, her, this, selection, pulsed, accomplices,
# Nearest to known: such, used, well, steffi, rsdlp, far, hoop, meddle,
# Nearest to to: will, may, not, would, mutant, massless, alastair, can,
# Nearest to only: until, agassi, stairs, teach, every, ecommerce, always, anticipates,
# Nearest to such: known, these, different, gabab, many, grotto, other, quality,
# Nearest to not: they, medications, also, it, still, usually, generally, to,
# Nearest to nine: eight, six, seven, five, four, zero, three, one,
# Nearest to all: many, some, several, these, luzon, kylix, metamorphism, depending,
# Nearest to over: hungry, publique, depression, catarina, flushed, network, reymond, vanished,
# Nearest to with: at, arndt, in, including, for, by, sainte, or,
# Nearest to first: second, ruud, slashdot, past, portman, best, medes, tf,
# Nearest to many: some, several, these, all, other, their, ausgleich, monuments,
# Nearest to b: d, avail, realtime, thule, uncountably, overthrowing, jihad, athletes,
# Nearest to had: has, have, was, were, paleontologists, started, accident, gigi,
# Nearest to he: it, she, they, who, there, summertime, coinage, we,
# Nearest to after: before, inuktitut, during, at, realisation, until, gbc, breuer,
# Average loss at step 22000: 3.500088
# Average loss at step 24000: 3.490430
# Average loss at step 26000: 3.476389
# Average loss at step 28000: 3.475135
# Average loss at step 30000: 3.501444
# Nearest to its: their, his, the, her, populous, laude, checks, crowell,
# Nearest to known: such, used, well, regarded, steffi, described, gangster, served,
# Nearest to to: would, will, can, not, could, baskets, baritone, should,
# Nearest to only: until, ecommerce, every, stairs, anticipates, moody, do, teach,
# Nearest to such: known, well, these, many, other, some, described, rader,
# Nearest to not: they, still, also, usually, it, to, generally, nullify,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to all: some, many, these, several, shrewd, any, always, luzon,
# Nearest to over: hungry, prickly, depression, parameter, hardness, vanished, besides, hair,
# Nearest to with: by, in, for, rouse, including, when, against, borders,
# Nearest to first: second, next, portman, last, past, best, ruud, fibres,
# Nearest to many: some, several, these, all, such, most, other, their,
# Nearest to b: d, avail, realtime, jihad, interwoven, litre, uncountably, stuttgart,
# Nearest to had: have, has, was, were, started, having, never, discernment,
# Nearest to he: she, it, they, who, there, never, we, summertime,
# Nearest to after: before, during, until, despite, realisation, when, for, was,
# Average loss at step 32000: 3.502814
# Average loss at step 34000: 3.495235
# Average loss at step 36000: 3.454505
# Average loss at step 38000: 3.296246
# Average loss at step 40000: 3.420754
# Nearest to its: their, his, the, her, laude, selection, crowell, tucker,
# Nearest to known: such, used, well, regarded, described, possible, gangster, considered,
# Nearest to to: will, could, would, can, baritone, may, elaborates, must,
# Nearest to only: always, every, ecommerce, never, until, mcintosh, multiverse, teach,
# Nearest to such: known, well, these, challenger, those, follows, grotto, miniscule,
# Nearest to not: still, often, they, it, usually, never, also, always,
# Nearest to nine: eight, seven, six, five, zero, four, three, one,
# Nearest to all: these, several, both, shrewd, any, some, many, always,
# Nearest to over: hungry, dams, depression, vanished, besides, subnet, museu, through,
# Nearest to with: when, including, by, arndt, on, between, contemplative, projected,
# Nearest to first: second, last, next, pike, ruud, portman, best, compensatory,
# Nearest to many: some, several, these, various, those, dari, all, most,
# Nearest to b: d, UNK, c, m, stuttgart, realtime, h, zeppelin,
# Nearest to had: has, have, was, were, already, batu, caught, rfc,
# Nearest to he: she, it, they, who, there, we, i, never,
# Nearest to after: before, during, realisation, when, herd, despite, bembo, until,
# Average loss at step 42000: 3.442177
# Average loss at step 44000: 3.448004
# Average loss at step 46000: 3.452050
# Average loss at step 48000: 3.354366
# Average loss at step 50000: 3.381054
# Nearest to its: their, his, the, her, selection, geopolitical, verdeans, our,
# Nearest to known: used, such, regarded, well, described, gangster, possible, benchmarks,
# Nearest to to: can, must, would, could, blanca, transcontinental, may, baritone,
# Nearest to only: always, potawatomi, predominate, firewire, still, until, never, scalpel,
# Nearest to such: well, known, these, many, follows, described, rader, challenger,
# Nearest to not: still, usually, generally, never, they, convinced, medications, often,
# Nearest to nine: eight, seven, six, four, zero, three, five, one,
# Nearest to all: both, these, some, any, many, narbonne, luzon, shrewd,
# Nearest to over: through, dams, besides, hungry, lennox, nara, depression, invests,
# Nearest to with: between, interrelated, contemplative, sainte, tact, harriers, arndt, articulated,
# Nearest to first: second, last, next, portman, ruud, tf, medes, lance,
# Nearest to many: some, several, these, various, both, those, different, such,
# Nearest to b: d, c, realtime, p, f, appliance, h, x,
# Nearest to had: has, have, was, were, already, having, paleontologists, did,
# Nearest to he: she, it, they, who, there, never, crosby, but,
# Nearest to after: before, during, when, despite, realisation, while, through, until,
# Average loss at step 52000: 3.434553
# Average loss at step 54000: 3.428719
# Average loss at step 56000: 3.432662
# Average loss at step 58000: 3.395172
# Average loss at step 60000: 3.395313
# Nearest to its: their, his, the, her, mnp, selection, several, scholz,
# Nearest to known: used, such, regarded, well, described, considered, gangster, possible,
# Nearest to to: would, will, must, may, might, can, canetti, and,
# Nearest to only: until, still, always, firewire, potawatomi, teach, loomis, first,
# Nearest to such: known, these, well, many, follows, described, including, regarded,
# Nearest to not: still, usually, never, generally, they, convinced, now, always,
# Nearest to nine: eight, six, four, five, seven, three, zero, one,
# Nearest to all: many, both, these, any, some, several, those, each,
# Nearest to over: through, between, depression, unpaid, landlocked, dams, reymond, about,
# Nearest to with: between, including, arndt, when, essentially, by, contemplative, articulated,
# Nearest to first: second, next, last, tf, portman, ruud, best, only,
# Nearest to many: some, several, various, these, both, all, most, such,
# Nearest to b: d, c, f, p, h, m, x, realtime,
# Nearest to had: has, have, was, having, were, already, paleontologists, undermined,
# Nearest to he: she, it, they, who, there, never, then, we,
# Nearest to after: before, during, when, despite, realisation, under, transposing, upon,
# Average loss at step 62000: 3.242215
# Average loss at step 64000: 3.250831
# Average loss at step 66000: 3.402128
# Average loss at step 68000: 3.395623
# Average loss at step 70000: 3.356643
# Nearest to its: their, his, the, her, our, scholz, coursing, float,
# Nearest to known: used, such, regarded, described, well, seen, gangster, benchmarks,
# Nearest to to: can, will, would, must, larva, could, and, for,
# Nearest to only: still, always, teach, actually, until, typically, never, potawatomi,
# Nearest to such: known, these, well, many, follows, certain, regarded, challenger,
# Nearest to not: still, never, generally, usually, now, always, convinced, often,
# Nearest to nine: eight, six, seven, five, four, zero, three, one,
# Nearest to all: many, some, any, these, both, several, every, those,
# Nearest to over: through, about, nara, landlocked, depression, unpaid, subnet, politicians,
# Nearest to with: between, arndt, moreover, including, contemplative, horizons, when, tact,
# Nearest to first: second, next, last, best, pike, original, ruud, same,
# Nearest to many: some, several, all, various, these, both, most, such,
# Nearest to b: d, h, f, r, x, fluorescence, p, hn,
# Nearest to had: has, have, having, was, were, been, rfc, paleontologists,
# Nearest to he: she, it, they, there, never, who, then, actually,
# Nearest to after: before, during, when, despite, realisation, while, herd, under,
# Average loss at step 72000: 3.373766
# Average loss at step 74000: 3.349289
# Average loss at step 76000: 3.314797
# Average loss at step 78000: 3.343356
# Average loss at step 80000: 3.377040
# Nearest to its: their, his, her, the, our, your, scholz, coursing,
# Nearest to known: used, regarded, such, described, seen, called, possible, gangster,
# Nearest to to: will, would, massless, should, potion, larva, claremont, could,
# Nearest to only: always, teach, firewire, either, until, mcintosh, still, just,
# Nearest to such: well, known, these, follows, certain, mazar, opposed, regarded,
# Nearest to not: still, usually, often, never, generally, always, it, almost,
# Nearest to nine: eight, seven, five, six, four, three, zero, two,
# Nearest to all: both, many, some, any, every, these, several, various,
# Nearest to over: nara, through, between, about, lennox, subnet, reymond, politicians,
# Nearest to with: between, including, tact, arndt, at, in, contemplative, against,
# Nearest to first: second, last, next, liquidation, same, suppressing, ruud, third,
# Nearest to many: some, several, various, these, all, both, most, those,
# Nearest to b: d, c, h, fluorescence, r, p, x, hn,
# Nearest to had: has, have, having, was, were, been, paleontologists, wanted,
# Nearest to he: she, it, they, there, who, never, we, strictest,
# Nearest to after: before, during, when, despite, realisation, while, until, herd,
# Average loss at step 82000: 3.411867
# Average loss at step 84000: 3.412667
# Average loss at step 86000: 3.384223
# Average loss at step 88000: 3.349342
# Average loss at step 90000: 3.364283
# Nearest to its: their, his, her, the, our, your, philosophies, ubu,
# Nearest to known: such, used, regarded, described, called, seen, possible, well,
# Nearest to to: towards, will, semiautomatic, would, elaborates, baritone, should, potion,
# Nearest to only: always, still, either, every, teach, no, just, lepidus,
# Nearest to such: known, well, follows, these, certain, many, opposed, monotonic,
# Nearest to not: still, never, we, better, generally, now, nor, medications,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to all: many, some, both, every, several, any, those, these,
# Nearest to over: through, about, nara, around, censored, revoke, extolling, sentinel,
# Nearest to with: between, contemplative, by, when, undercarriage, in, across, horizons,
# Nearest to first: second, last, next, laodiceans, original, portman, same, suppressing,
# Nearest to many: some, several, various, these, all, those, most, numerous,
# Nearest to b: d, h, c, fluorescence, r, pp, hn, k,
# Nearest to had: has, have, was, were, having, since, paleontologists, attempted,
# Nearest to he: she, it, they, there, who, never, then, later,
# Nearest to after: before, during, when, despite, realisation, while, until, through,
# Average loss at step 92000: 3.395120
# Average loss at step 94000: 3.252159
# Average loss at step 96000: 3.353540
# Average loss at step 98000: 3.239880
# Average loss at step 100000: 3.356271
# Nearest to its: their, his, her, the, our, bluetooth, geopolitical, several,
# Nearest to known: regarded, such, possible, used, described, seen, defined, well,
# Nearest to to: could, will, would, must, should, can, towards, thoroughfare,
# Nearest to only: still, never, always, loomis, firewire, actually, until, salvo,
# Nearest to such: known, well, many, follows, certain, these, opposed, regarded,
# Nearest to not: never, still, almost, nor, t, they, easily, zahn,
# Nearest to nine: eight, seven, six, four, five, zero, three, one,
# Nearest to all: many, both, every, some, any, various, several, these,
# Nearest to over: through, dresser, around, nearly, nara, isn, sentinel, lennox,
# Nearest to with: contemplative, between, including, when, esotericism, using, rowspan, horizons,
# Nearest to first: second, last, next, fourth, third, portman, home, best,
# Nearest to many: some, several, various, these, such, all, few, those,
# Nearest to b: d, realtime, accrue, interwoven, overthrowing, uncountably, pp, avail,
# Nearest to had: has, have, was, having, would, were, since, undermined,
# Nearest to he: she, it, they, who, there, we, never, summertime,
# Nearest to after: before, during, when, despite, realisation, without, until, while,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# I've changed from  tf.nn.sampled_softmax_loss to tf.nn.nce_loss. It seems to be no specific reason for me to change like that.

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# 1. skilgram model
#    : "predicting the context given a word".
# (originated, as), (originated, anarchism), (as, a), (as, originated), ...
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
#
# 2. Continuous Bag of Words
#    : "predicting the word given its context"
# ([anachism, as], originated), ([originated, a], as), ([as, term], a), ...

# %%
data_index = 0

def generate_batch(batch_size, bag_window, skip_window=1):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size,num_skips * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
   # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.404818
# Nearest to see: visitor, marek, zhang, grissom, studio, krieg, da, hannity,
# Nearest to after: unto, benny, supplement, sdlp, daniels, ilinden, ernie, aerosmith,
# Nearest to use: parlay, maghrib, connect, teutons, lifespans, tapu, funny, bonham,
# Nearest to three: bothnian, harcourt, bremer, nominative, quantitatively, abject, xinjiang, marienburg,
# Nearest to their: dorset, asterisk, htp, ingress, apuleius, founders, centred, heaped,
# Nearest to five: faso, pow, porting, miscellany, salvator, mok, sumo, electronegativity,
# Nearest to some: melville, debuted, removed, subsets, anyway, blass, criminology, cyrillic,
# Nearest to world: tal, milford, neurologic, associations, regression, fractions, proclus, adjectival,
# Nearest to in: millicent, cooper, alternatives, cay, lakeshore, hales, subordination, famer,
# Nearest to i: ingham, litigated, famine, charts, summit, plaintexts, swiss, complexity,
# Nearest to united: folio, porky, erickson, lute, particles, spr, perturbations, transcendent,
# Nearest to two: repose, meuse, bridges, prespa, amtrak, del, decrypt, issuer,
# Nearest to however: dunn, heighten, duplex, texan, oxidise, brad, contain, gary,
# Nearest to UNK: kingdom, snowmobile, atalanta, friend, malabar, desirable, bosch, fronted,
# Nearest to over: gnasher, prints, timaeus, stoughton, deseret, proliferation, implicit, vulture,
# Nearest to the: cheerleaders, monitors, boast, diesels, amos, serving, cooker, emery,
# Average loss at step 2000: 10.585535
# Average loss at step 4000: 4.676423
# Average loss at step 6000: 4.135280
# Average loss at step 8000: 4.395396
# Average loss at step 10000: 4.326326
# Nearest to see: auteurs, canons, amazons, decision, truetype, disadvantage, aries, apple,
# Nearest to after: before, flinders, montfort, quartered, cricket, collating, galvani, variadic,
# Nearest to use: truetype, canons, apple, auteurs, eight, hits, amethyst, general,
# Nearest to three: five, h, seven, two, perceptible, deny, linking, crist,
# Nearest to their: its, some, his, any, shut, both, flee, pisces,
# Nearest to five: eight, canons, truetype, auteurs, apple, hits, lower, general,
# Nearest to some: apple, truetype, canons, lower, aisles, auteurs, eight, unalaska,
# Nearest to world: mid, convention, villages, thing, excessively, bavarian, story, braddock,
# Nearest to in: on, during, trackball, since, typewriters, amides, topologies, stipulations,
# Nearest to i: ii, universality, we, g, recognising, vogt, accumulations, avtovaz,
# Nearest to united: southern, shrinking, quiet, werewolves, ensure, hubert, accede, sih,
# Nearest to two: five, eight, truetype, lower, canons, apple, general, auteurs,
# Nearest to however: glycolytic, fiske, but, bau, leigh, masuria, dov, minimalistic,
# Nearest to UNK: american, r, john, aberdeen, amazons, violet, h, canons,
# Nearest to over: vulture, glas, gurney, prester, pickard, parole, strides, recognising,
# Nearest to the: its, a, his, bouts, observance, this, cheerleading, vargas,
# Average loss at step 12000: 3.846360
# Average loss at step 14000: 3.686457
# Average loss at step 16000: 3.749996
# Average loss at step 18000: 3.720018
# Average loss at step 20000: 3.412931
# Nearest to see: joseph, probes, mint, grissom, balas, uae, fringing, introduced,
# Nearest to after: before, during, following, when, for, collating, claudius, diplomats,
# Nearest to use: byrnes, lifespans, manufactured, provide, grandiose, usage, hark, alternatives,
# Nearest to three: two, five, four, six, all, eight, seven, hole,
# Nearest to their: its, his, her, the, your, instalments, other, ailment,
# Nearest to five: six, four, three, seven, eight, zero, two, hole,
# Nearest to some: many, several, various, these, boswell, both, most, different,
# Nearest to world: mana, barbed, loosely, unexplored, story, mid, ancestry, figurehead,
# Nearest to in: during, on, since, enriched, linebacker, protecting, between, throughout,
# Nearest to i: we, g, d, star, turner, adobe, odd, ii,
# Nearest to united: southern, hubert, serbians, reconquered, bounced, samuel, vassal, quiet,
# Nearest to two: three, all, four, akademie, five, hours, flemish, tuned,
# Nearest to however: that, but, jizya, where, montenegrin, dumont, while, expressway,
# Nearest to UNK: mary, english, truetype, d, canons, brecht, arsenal, altair,
# Nearest to over: extremities, yiddish, pipelines, norms, recognising, vulture, shelved, msc,
# Nearest to the: their, a, his, its, this, an, each, any,
# Average loss at step 22000: 3.592366
# Average loss at step 24000: 3.545830
# Average loss at step 26000: 3.477694
# Average loss at step 28000: 3.490529
# Average loss at step 30000: 3.683947
# Nearest to see: joseph, clapton, rattus, viewing, rallied, but, fringing, centrioles,
# Nearest to after: before, during, dheas, straining, through, within, when, alto,
# Nearest to use: form, intervals, alexandrovna, release, byrnes, hippo, offerings, endeavor,
# Nearest to three: four, five, six, eight, balder, flintlock, seven, bertolt,
# Nearest to their: its, his, her, the, our, my, gard, both,
# Nearest to five: four, six, three, eight, wootz, louvain, paradiso, per,
# Nearest to some: many, several, all, both, various, most, golovachev, sonia,
# Nearest to world: hammerheads, thiele, glaser, interchanged, loosely, receiver, mid, boiled,
# Nearest to in: during, within, throughout, since, on, macon, until, between,
# Nearest to i: ii, g, synclavier, slums, beget, preferential, albatrosses, wiles,
# Nearest to united: truth, ensure, general, serving, company, resistant, descended, algebra,
# Nearest to two: nine, zero, deregulated, position, english, one, americanism, ds,
# Nearest to however: although, but, though, because, if, and, until, tour,
# Nearest to UNK: l, miner, spoken, j, dr, mary, river, catalan,
# Nearest to over: around, before, about, cups, yiddish, overhead, vulture, hemionus,
# Nearest to the: its, their, a, our, his, svc, this, lind,
# Average loss at step 32000: 3.157837
# Average loss at step 34000: 3.425613
# Average loss at step 36000: 3.486117
# Average loss at step 38000: 3.375020
# Average loss at step 40000: 3.314166
# Nearest to see: rta, balas, called, includes, purists, keith, but, joseph,
# Nearest to after: before, during, when, since, as, within, for, following,
# Nearest to use: because, form, share, version, endeavor, development, alternatives, lack,
# Nearest to three: five, four, two, six, eight, seven, several, stadtbahn,
# Nearest to their: its, his, her, my, the, our, your, other,
# Nearest to five: three, eight, six, four, zero, seven, two, kneel,
# Nearest to some: many, several, employment, most, certain, partnerships, various, booklet,
# Nearest to world: nation, u, hammerheads, valeria, interchanged, monk, uk, ablaze,
# Nearest to in: within, throughout, during, since, sharpened, on, through, macon,
# Nearest to i: g, ii, sul, turner, peculiarities, thirty, friction, beget,
# Nearest to united: sloped, reconquered, southern, vassal, emerge, lute, buds, vantaa,
# Nearest to two: three, five, loos, trout, four, supple, xix, consolidating,
# Nearest to however: although, but, though, while, since, and, that, until,
# Nearest to UNK: empiricist, beside, farnese, anchored, henotheism, ne, beyer, lowe,
# Nearest to over: around, about, across, between, at, before, within, during,
# Nearest to the: its, their, a, this, his, unintended, lind, any,
# Average loss at step 42000: 3.343119
# Average loss at step 44000: 3.235992
# Average loss at step 46000: 3.270724
# Average loss at step 48000: 3.252377
# Average loss at step 50000: 3.215743
# Nearest to see: grand, auteurs, aries, supplying, syntactically, although, unalaska, multiplicative,
# Nearest to after: before, during, following, despite, when, dheas, for, bethany,
# Nearest to use: development, share, endeavor, usage, favor, work, purim, source,
# Nearest to three: four, five, six, seven, eight, servicing, kora, agricola,
# Nearest to their: its, his, our, your, her, my, the, both,
# Nearest to five: four, six, three, eight, seven, two, clustering, mobil,
# Nearest to some: many, several, certain, various, multiple, any, all, numerous,
# Nearest to world: studi, degli, di, universit, bronze, boolean, arsenal, class,
# Nearest to in: within, during, throughout, until, from, since, on, pravda,
# Nearest to i: ii, g, we, beget, iii, vogt, you, nostalgic,
# Nearest to united: emerge, vassal, erickson, reconquered, leaky, facilitates, accordance, eulogy,
# Nearest to two: five, four, zero, flotilla, epitaph, atalanta, warms, seizing,
# Nearest to however: though, since, but, that, nir, because, heyerdahl, while,
# Nearest to UNK: www, lat, empiricist, chronicler, jackson, augustin, compressive, nauvoo,
# Nearest to over: around, across, yiddish, crystal, msc, pequod, recognising, long,
# Nearest to the: a, its, an, his, their, another, this, vargas,
# Average loss at step 52000: 3.266173
# Average loss at step 54000: 3.198705
# Average loss at step 56000: 3.029320
# Average loss at step 58000: 3.092726
# Average loss at step 60000: 3.148180
# Nearest to see: include, keith, includes, rta, but, balas, caius, overpower,
# Nearest to after: during, before, following, despite, dheas, since, afterwards, straining,
# Nearest to use: share, grandiose, endeavor, form, wootz, mistakes, intervals, rewrites,
# Nearest to three: four, six, seven, two, eight, five, several, zero,
# Nearest to their: its, his, her, our, your, my, the, whose,
# Nearest to five: six, eight, four, seven, zero, mars, two, km,
# Nearest to some: many, several, various, certain, all, most, millions, both,
# Nearest to world: country, apple, metal, tour, totaling, eye, vietnam, cent,
# Nearest to in: within, during, throughout, since, bowen, on, amides, from,
# Nearest to i: ii, you, vogt, we, iii, g, tit, wreck,
# Nearest to united: pharmacological, butch, eyewitness, erickson, reconquered, cornerstones, disadvantageous, werewolves,
# Nearest to two: three, five, four, six, zero, apart, attaining, iudex,
# Nearest to however: although, though, but, that, lao, while, entrepreneur, heyerdahl,
# Nearest to UNK: gaels, hardwoods, bleue, boece, malleus, mesogens, inductively, hominid,
# Nearest to over: through, about, around, across, throughout, nearly, knebworth, beyond,
# Nearest to the: his, a, its, their, any, another, svc, an,
# Average loss at step 62000: 3.090739
# Average loss at step 64000: 2.982490
# Average loss at step 66000: 3.032414
# Average loss at step 68000: 3.087388
# Average loss at step 70000: 3.088475
# Nearest to see: sahara, provides, procol, eesti, ruppert, reduce, miner, eye,
# Nearest to after: before, following, during, despite, afterwards, when, for, from,
# Nearest to use: mistakes, rewrites, ghettos, share, play, alternatives, version, list,
# Nearest to three: five, six, four, two, seven, eight, zero, switzer,
# Nearest to their: its, his, her, our, your, the, my, whose,
# Nearest to five: six, seven, three, eight, four, zero, two, n,
# Nearest to some: many, several, certain, various, all, numerous, multiple, millions,
# Nearest to world: second, interchanged, spilled, apple, hotham, u, debate, nation,
# Nearest to in: throughout, during, within, at, on, outside, before, around,
# Nearest to i: ii, you, g, constable, we, they, iii, wreck,
# Nearest to united: eyewitness, leaky, werewolves, butch, pharmacological, vassal, punts, israeli,
# Nearest to two: three, zero, five, harun, ireann, four, eight, six,
# Nearest to however: although, though, since, but, heyerdahl, while, omen, fgm,
# Nearest to UNK: magnum, royal, wolfgang, container, relinquished, www, paige, scouting,
# Nearest to over: throughout, around, through, recognising, about, within, nearly, extremities,
# Nearest to the: their, its, a, his, our, any, this, another,
# Average loss at step 72000: 3.018567
# Average loss at step 74000: 2.919064
# Average loss at step 76000: 3.070278
# Average loss at step 78000: 3.062709
# Average loss at step 80000: 2.913096
# Nearest to see: but, includes, ruppert, balas, makes, rta, saw, ita,
# Nearest to after: before, following, when, despite, afterwards, though, upon, since,
# Nearest to use: extent, form, practice, support, parts, share, list, nucleic,
# Nearest to three: five, six, four, seven, eight, two, ten, zero,
# Nearest to their: his, its, our, your, her, my, the, whose,
# Nearest to five: three, six, four, seven, eight, zero, wynne, lunatics,
# Nearest to some: many, certain, several, various, all, most, thousands, multiple,
# Nearest to world: meritorious, pacific, spilled, interchanged, liturgy, novel, donnell, raid,
# Nearest to in: within, throughout, including, on, through, from, among, banchan,
# Nearest to i: ii, g, you, we, ragnar, iii, they, wreck,
# Nearest to united: crichton, eyewitness, confederate, microcode, werewolves, vassal, reconquered, accordance,
# Nearest to two: three, iudex, six, four, annulment, individualist, ubiquity, takla,
# Nearest to however: although, though, but, since, because, if, unlike, when,
# Nearest to UNK: chun, r, vladimir, moldovan, claudian, und, ltte, swedish,
# Nearest to over: around, through, nearly, about, throughout, overlay, recognising, across,
# Nearest to the: another, any, its, a, their, an, our, ruud,
# Average loss at step 82000: 2.995518
# Average loss at step 84000: 2.955152
# Average loss at step 86000: 2.968936
# Average loss at step 88000: 2.995606
# Average loss at step 90000: 2.889061
# Nearest to see: includes, ruppert, but, balas, contains, alekhine, include, allow,
# Nearest to after: before, despite, following, during, when, straining, afterwards, dheas,
# Nearest to use: share, usage, form, ghettos, list, copies, grandiose, version,
# Nearest to three: five, seven, six, four, two, zero, almoravid, one,
# Nearest to their: its, his, your, our, her, my, the, these,
# Nearest to five: six, four, three, seven, zero, eight, nine, stylings,
# Nearest to some: many, all, various, several, most, numerous, rats, fighters,
# Nearest to world: liturgy, meritorious, country, wept, u, pyrotechnics, solnhofen, nation,
# Nearest to in: throughout, within, outside, since, where, on, after, despite,
# Nearest to i: g, ii, we, sul, minting, constable, acute, wreck,
# Nearest to united: eyewitness, werewolves, israeli, us, crichton, vassal, reformulation, emerge,
# Nearest to two: four, three, six, one, nine, downs, thereof, plug,
# Nearest to however: although, though, but, since, while, when, and, where,
# Nearest to UNK: www, shropshire, breton, jos, gabriel, arcologies, discography, ivan,
# Nearest to over: around, about, nearly, across, within, throughout, extremities, through,
# Nearest to the: its, a, his, their, an, our, any, juggalos,
# Average loss at step 92000: 2.983713
# Average loss at step 94000: 2.952925
# Average loss at step 96000: 2.762789
# Average loss at step 98000: 2.501582
# Average loss at step 100000: 2.769695
# Nearest to see: include, modus, references, allow, called, contains, includes, saw,
# Nearest to after: before, despite, following, when, afterwards, upon, during, straining,
# Nearest to use: sickle, brecht, canons, studi, tour, porter, arsenal, nfl,
# Nearest to three: four, six, seven, eight, five, two, zero, whistle,
# Nearest to their: its, his, her, our, your, the, my, s,
# Nearest to five: seven, four, six, eight, three, zero, round, gabriel,
# Nearest to some: many, various, several, numerous, most, any, all, certain,
# Nearest to world: meritorious, pacific, spilled, galaxy, solnhofen, aztecs, u, medalists,
# Nearest to in: during, outside, throughout, within, near, on, at, despite,
# Nearest to i: ii, we, g, you, iii, nast, iv, constable,
# Nearest to united: us, confederate, eyewitness, emerge, uralic, falla, leaky, israeli,
# Nearest to two: three, four, six, five, harun, lonergan, treviso, cet,
# Nearest to however: show, provided, porter, reflect, wreckin, cronus, universit, acad,
# Nearest to UNK: yevgeny, ltte, riso, rhineland, interlingua, med, hohenstaufen, arcologies,
# Nearest to over: nearly, around, through, across, extremities, during, throughout, staking,
# Nearest to the: a, its, his, their, her, our, svc, another,
